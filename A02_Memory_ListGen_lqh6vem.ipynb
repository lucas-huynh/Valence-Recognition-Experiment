# %% [markdown]
# Section 1. Import packages and create empty lists to store trials.

# %%
import csv
import random
from copy import deepcopy

pos_pool = []  # List to store positive words
neg_pool = []  # List to store negative words
neu_pool = []   # List to store neutral words

# %% [markdown]
# Section 2. Read the files and make list of dictionaries for each pool.

# %%
with open('pos_pool.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    pos_pool = [l for l in reader]
    print(pos_pool)

with open('neg_pool.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    neg_pool = [l for l in reader]
    print(neg_pool)

with open('neu_pool.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    neu_pool = [l for l in reader]
    print(neu_pool)
# Out:
# [{'description': 'abundance', 'word_no': '624', 'valence_mean': '6.5899999999999999', 'valence_sd': '2.0099999999999998', 'arousal_mean': '5.5099999999999998', 'arousal_sd': '2.6299999999999999', 'dominance_mean': '5.7999999999999998', 'dominance_sd': '2.1600000000000001', 'word_frequency': '13'}, {'description': 'acceptance', 'word_no': '625', 'valence_mean': '7.9800000000000004', 'valence_sd': '1.4199999999999999', 'arousal_mean': '5.4000000000000004', 'arousal_sd': '2.7000000000000002', 'dominance_mean': '6.6399999999999997', 'dominance_sd': '1.9099999999999999', 'word_frequency': '49'}, {'description': 'ace', 'word_no': '626', 'valence_mean': '6.8799999999999999', 'valence_sd': '1.9299999999999999', 'arousal_mean': '5.5', 'arousal_sd': '2.6600000000000001', 'dominance_mean': '6.3899999999999997', 'dominance_sd': '2.3100000000000001', 'word_frequency': '15'}, {'description': 'achievement', 'word_no': '3', 'valence_mean': '7.8899999999999997', 'valence_sd': '1.3799999999999999', 'arousal_mean': '5.5300000000000002', 'arousal_sd': '2.8100000000000001', 'dominance_mean': '6.5599999999999996', 'dominance_sd': '2.3500000000000001', 'word_frequency': '65'}, {'description': 'admired', 'word_no': '5', 'valence_mean': '7.7400000000000002', 'valence_sd': '1.8400000000000001', 'arousal_mean': '6.1100000000000003', 'arousal_sd': '2.3599999999999999', 'dominance_mean': '7.5300000000000002', 'dominance_sd': '1.9399999999999999', 'word_frequency': '17'}, {'description': 'adorable', 'word_no': '6', 'valence_mean': '7.8099999999999996', 'valence_sd': '1.24', 'arousal_mean': '5.1200000000000001', 'arousal_sd': '2.71', 'dominance_mean': '5.7400000000000002', 'dominance_sd': '2.48', 'word_frequency': '3'}, {'description': 'advantage', 'word_no': '629', 'valence_mean': '6.9500000000000002', 'valence_sd': '1.8500000000000001', 'arousal_mean': '4.7599999999999998', 'arousal_sd': '2.1800000000000002', 'dominance_mean': '6.3600000000000003', 'dominance_sd': '2.23', 'word_frequency': '73'}, {'description': 'adventure', 'word_no': '630', 'valence_mean': '7.5999999999999996', 'valence_sd': '1.5', 'arousal_mean': '6.9800000000000004', 'arousal_sd': '2.1499999999999999', 'dominance_mean': '6.46', 'dominance_sd': '1.6699999999999999', 'word_frequency': '14'}, {'description': 'agreement', 'word_no': '631', 'valence_mean': '7.0800000000000001', 'valence_sd': '1.5900000000000001', 'arousal_mean': '5.0199999999999996', 'arousal_sd': '2.2400000000000002', 'dominance_mean': '6.2199999999999998', 'dominance_sd': '1.8500000000000001', 'word_frequency': '106'}, {'description': 'alive', 'word_no': '635', 'valence_mean': '7.25', 'valence_sd': '2.2200000000000002', 'arousal_mean': '5.5', 'arousal_sd': '2.7400000000000002', 'dominance_mean': '6.3899999999999997', 'dominance_sd': '2.1499999999999999', 'word_frequency': '57'}, {'description': 'ambition', 'word_no': '14', 'valence_mean': '7.04', 'valence_sd': '1.98', 'arousal_mean': '5.6100000000000003', 'arousal_sd': '2.9199999999999999', 'dominance_mean': '6.9299999999999997', 'dominance_sd': '2.0699999999999998', 'word_frequency': '19'}, {'description': 'angel', 'word_no': '16', 'valence_mean': '7.5300000000000002', 'valence_sd': '1.5800000000000001', 'arousal_mean': '4.8300000000000001', 'arousal_sd': '2.6299999999999999', 'dominance_mean': '4.9699999999999998', 'dominance_sd': '2.3399999999999999', 'word_frequency': '18'}, {'description': 'answer', 'word_no': '639', 'valence_mean': '6.6299999999999999', 'valence_sd': '1.6799999999999999', 'arousal_mean': '5.4100000000000001', 'arousal_sd': '2.4300000000000002', 'dominance_mean': '5.8499999999999996', 'dominance_sd': '1.8799999999999999', 'word_frequency': '152'}, {'description': 'applause', 'word_no': '640', 'valence_mean': '7.5', 'valence_sd': '1.5', 'arousal_mean': '5.7999999999999998', 'arousal_sd': '2.79', 'dominance_mean': '6.4800000000000004', 'dominance_sd': '2.1099999999999999', 'word_frequency': '14'}, {'description': 'aroused', 'word_no': '24', 'valence_m ...
# [{'description': 'abduction', 'word_no': '621', 'valence_mean': '2.7599999999999998', 'valence_sd': '2.0600000000000001', 'arousal_mean': '5.5300000000000002', 'arousal_sd': '2.4300000000000002', 'dominance_mean': '3.4900000000000002', 'dominance_sd': '2.3799999999999999', 'word_frequency': '1'}, {'description': 'abortion', 'word_no': '622', 'valence_mean': '3.5', 'valence_sd': '2.2999999999999998', 'arousal_mean': '5.3899999999999997', 'arousal_sd': '2.7999999999999998', 'dominance_mean': '4.5899999999999999', 'dominance_sd': '2.54', 'word_frequency': '6'}, {'description': 'accident', 'word_no': '2', 'valence_mean': '2.0499999999999998', 'valence_sd': '1.1899999999999999', 'arousal_mean': '6.2599999999999998', 'arousal_sd': '2.8700000000000001', 'dominance_mean': '3.7599999999999998', 'dominance_sd': '2.2200000000000002', 'word_frequency': '33'}, {'description': 'ache', 'word_no': '627', 'valence_mean': '2.46', 'valence_sd': '1.52', 'arousal_mean': '5.0', 'arousal_sd': '2.4500000000000002', 'dominance_mean': '3.54', 'dominance_sd': '1.73', 'word_frequency': '4'}, {'description': 'addict', 'word_no': '581', 'valence_mean': '2.48', 'valence_sd': '2.0800000000000001', 'arousal_mean': '5.6600000000000001', 'arousal_sd': '2.2599999999999998', 'dominance_mean': '3.7200000000000002', 'dominance_sd': '2.54', 'word_frequency': '1'}, {'description': 'addicted', 'word_no': '628', 'valence_mean': '2.5099999999999998', 'valence_sd': '1.4199999999999999', 'arousal_mean': '4.8099999999999996', 'arousal_sd': '2.46', 'dominance_mean': '3.46', 'dominance_sd': '2.23', 'word_frequency': '3'}, {'description': 'agony', 'word_no': '10', 'valence_mean': '2.4300000000000002', 'valence_sd': '2.1699999999999999', 'arousal_mean': '6.0599999999999996', 'arousal_sd': '2.6699999999999999', 'dominance_mean': '4.0199999999999996', 'dominance_sd': '2.4900000000000002', 'word_frequency': '9'}, {'description': 'alcoholic', 'word_no': '582', 'valence_mean': '2.8399999999999999', 'valence_sd': '2.3399999999999999', 'arousal_mean': '5.6900000000000004', 'arousal_sd': '2.3599999999999999', 'dominance_mean': '4.4500000000000002', 'dominance_sd': '2.5600000000000001', 'word_frequency': '3'}, {'description': 'alimony', 'word_no': '634', 'valence_mean': '3.9500000000000002', 'valence_sd': '2.0', 'arousal_mean': '4.2999999999999998', 'arousal_sd': '2.29', 'dominance_mean': '4.6299999999999999', 'dominance_sd': '2.2999999999999998', 'word_frequency': '2'}, {'description': 'allergy', 'word_no': '636', 'valence_mean': '3.0699999999999998', 'valence_sd': '1.6399999999999999', 'arousal_mean': '4.6399999999999997', 'arousal_sd': '2.3399999999999999', 'dominance_mean': '3.21', 'dominance_sd': '1.77', 'word_frequency': '1'}, {'description': 'alone', 'word_no': '12', 'valence_mean': '2.4100000000000001', 'valence_sd': '1.77', 'arousal_mean': '4.8300000000000001', 'arousal_sd': '2.6600000000000001', 'dominance_mean': '3.7000000000000002', 'dominance_sd': '2.4199999999999999', 'word_frequency': '195'}, {'description': 'anguished', 'word_no': '19', 'valence_mean': '2.1200000000000001', 'valence_sd': '1.5600000000000001', 'arousal_mean': '5.3300000000000001', 'arousal_sd': '2.6899999999999999', 'dominance_mean': '3.4500000000000002', 'dominance_sd': '2.3700000000000001', 'word_frequency': '2'}, {'description': 'arrogant', 'word_no': '25', 'valence_mean': '3.6899999999999999', 'valence_sd': '2.3999999999999999', 'arousal_mean': '5.6500000000000004', 'arousal_sd': '2.23', 'dominance_mean': '5.1399999999999997', 'dominance_sd': '2.71', 'word_frequency': '2'}, {'description': 'assassin', 'word_no': '26', 'valence_mean': '3.0899999999999999', 'valence_sd': '2.0899999999999999', 'arousal_mean': '6.2800000000000002', 'arousal_sd': '2.5299999999999998', 'dominance_mean': '4.3300000000000001', 'dominance_sd': '2.6800000000000002', 'word_frequency': '6'}, {'description': 'avalanche', 'word_no': '645', 'valence_mean': '3.29', 'valence_sd': '1.95', 'arousal_mean': '5.54', 'arousal_sd': '2.37000 ...
# [{'description': 'activate', 'word_no': '4', 'valence_mean': '5.46', 'valence_sd': '0.97999999999999998', 'arousal_mean': '4.8600000000000003', 'arousal_sd': '2.5600000000000001', 'dominance_mean': '5.4299999999999997', 'dominance_sd': '1.8400000000000001', 'word_frequency': '2'}, {'description': 'alien', 'word_no': '633', 'valence_mean': '5.5999999999999996', 'valence_sd': '1.8200000000000001', 'arousal_mean': '5.4500000000000002', 'arousal_sd': '2.1499999999999999', 'dominance_mean': '4.6399999999999997', 'dominance_sd': '2.0699999999999998', 'word_frequency': '16'}, {'description': 'aloof', 'word_no': '13', 'valence_mean': '4.9000000000000004', 'valence_sd': '1.9199999999999999', 'arousal_mean': '4.2800000000000002', 'arousal_sd': '2.1000000000000001', 'dominance_mean': '4.6900000000000004', 'dominance_sd': '1.9199999999999999', 'word_frequency': '5'}, {'description': 'ankle', 'word_no': '638', 'valence_mean': '5.2699999999999996', 'valence_sd': '1.54', 'arousal_mean': '4.1600000000000001', 'arousal_sd': '2.0299999999999998', 'dominance_mean': '4.7699999999999996', 'dominance_sd': '1.74', 'word_frequency': '8'}, {'description': 'appliance', 'word_no': '641', 'valence_mean': '5.0999999999999996', 'valence_sd': '1.21', 'arousal_mean': '4.0499999999999998', 'arousal_sd': '2.0600000000000001', 'dominance_mean': '5.0499999999999998', 'dominance_sd': '1.3400000000000001', 'word_frequency': '5'}, {'description': 'arm', 'word_no': '642', 'valence_mean': '5.3399999999999999', 'valence_sd': '1.8200000000000001', 'arousal_mean': '3.5899999999999999', 'arousal_sd': '2.3999999999999999', 'dominance_mean': '5.0700000000000003', 'dominance_sd': '1.5', 'word_frequency': '94'}, {'description': 'army', 'word_no': '23', 'valence_mean': '4.7199999999999998', 'valence_sd': '1.75', 'arousal_mean': '5.0300000000000002', 'arousal_sd': '2.0299999999999998', 'dominance_mean': '5.0300000000000002', 'dominance_sd': '2.4500000000000002', 'word_frequency': '132'}, {'description': 'avenue', 'word_no': '646', 'valence_mean': '5.5', 'valence_sd': '1.3700000000000001', 'arousal_mean': '4.1200000000000001', 'arousal_sd': '2.0099999999999998', 'dominance_mean': '5.4000000000000004', 'dominance_sd': '1.53', 'word_frequency': '46'}, {'description': 'banner', 'word_no': '649', 'valence_mean': '5.4000000000000004', 'valence_sd': '0.82999999999999996', 'arousal_mean': '3.8300000000000001', 'arousal_sd': '1.95', 'dominance_mean': '4.7999999999999998', 'dominance_sd': '1.5700000000000001', 'word_frequency': '8'}, {'description': 'barrel', 'word_no': '651', 'valence_mean': '5.0499999999999998', 'valence_sd': '1.46', 'arousal_mean': '3.3599999999999999', 'arousal_sd': '2.2799999999999998', 'dominance_mean': '4.8899999999999997', 'dominance_sd': '1.5700000000000001', 'word_frequency': '24'}, {'description': 'basket', 'word_no': '547', 'valence_mean': '5.4500000000000002', 'valence_sd': '1.1499999999999999', 'arousal_mean': '3.6299999999999999', 'arousal_sd': '2.02', 'dominance_mean': '5.7599999999999998', 'dominance_sd': '1.45', 'word_frequency': '17'}, {'description': 'bathroom', 'word_no': '548', 'valence_mean': '5.5499999999999998', 'valence_sd': '1.3600000000000001', 'arousal_mean': '3.8799999999999999', 'arousal_sd': '1.72', 'dominance_mean': '5.6500000000000004', 'dominance_sd': '1.5900000000000001', 'word_frequency': '18'}, {'description': 'bench', 'word_no': '655', 'valence_mean': '4.6100000000000003', 'valence_sd': '1.3999999999999999', 'arousal_mean': '3.5899999999999999', 'arousal_sd': '2.0699999999999998', 'dominance_mean': '4.6799999999999997', 'dominance_sd': '1.3799999999999999', 'word_frequency': '35'}, {'description': 'black', 'word_no': '543', 'valence_mean': '5.3899999999999997', 'valence_sd': '1.8', 'arousal_mean': '4.6100000000000003', 'arousal_sd': '2.2400000000000002', 'dominance_mean': '5.1399999999999997', 'dominance_sd': '1.79', 'word_frequency': '203'}, {'description': 'blase', 'word_no': '41', 'valence_mean': '4.8899999999999997', 'valence_s ...

# %% [markdown]
# Section 3. Cross all valence descriptions (+,-,~) with all conditions (repeated, refreshed, once-presented); create study list

# %%
conditions = ["repeated","refreshed","once-presented"]
temp_study_list = []
fin_study_list = []
num_words = 3

random.shuffle(pos_pool)
pos_select = pos_pool[:num_words] #can change number of words here
for i in range(num_words):
    cond_item = {'valence': 'pos', 'pres_num': 1}
    cond_item.update({'cond': conditions[i%3]})
    cond_item.update(pos_select[i])
    temp_study_list.append(cond_item)
        
random.shuffle(neg_pool)
neg_select = neg_pool[:num_words] #can change number of words here
for i in range(num_words):
    cond_item = {'valence': 'neg', 'pres_num': 1}
    cond_item.update({'cond': conditions[i%3]})
    cond_item.update(neg_select[i])
    temp_study_list.append(cond_item)
        
random.shuffle(neu_pool)
neu_select = neu_pool[:num_words] #can change number of words here
for i in range(num_words):
    cond_item = {'valence': 'neu', 'pres_num': 1}
    cond_item.update({'cond': conditions[i%3]})
    cond_item.update(neu_select[i])
    temp_study_list.append(cond_item)

random.shuffle(temp_study_list)

for word in temp_study_list:
    fin_study_list.append(word)
    if word['cond'] == "repeated":
        next_item = deepcopy(word)
        next_item['pres_num'] = 2
        fin_study_list.append(next_item)
    elif word['cond'] == "refreshed":
        next_item = deepcopy(word)
        next_item['description'] = '+'
        next_item['pres_num'] = 2
        fin_study_list.append(next_item)

for word in fin_study_list:
    print(word)
    print()
# Out:
# {'valence': 'neu', 'pres_num': 1, 'cond': 'repeated', 'description': 'table', 'word_no': '426', 'valence_mean': '5.2199999999999998', 'valence_sd': '0.71999999999999997', 'arousal_mean': '2.9199999999999999', 'arousal_sd': '2.1600000000000001', 'dominance_mean': '4.4699999999999998', 'dominance_sd': '1.6599999999999999', 'word_frequency': '198'}
#
# {'valence': 'neu', 'pres_num': 2, 'cond': 'repeated', 'description': 'table', 'word_no': '426', 'valence_mean': '5.2199999999999998', 'valence_sd': '0.71999999999999997', 'arousal_mean': '2.9199999999999999', 'arousal_sd': '2.1600000000000001', 'dominance_mean': '4.4699999999999998', 'dominance_sd': '1.6599999999999999', 'word_frequency': '198'}
#
# {'valence': 'neu', 'pres_num': 1, 'cond': 'once-presented', 'description': 'concentrate', 'word_no': '78', 'valence_mean': '5.2000000000000002', 'valence_sd': '1.28', 'arousal_mean': '4.6500000000000004', 'arousal_sd': '2.1299999999999999', 'dominance_mean': '4.9699999999999998', 'dominance_sd': '1.75', 'word_frequency': '11'}
#
# {'valence': 'neg', 'pres_num': 1, 'cond': 'repeated', 'description': 'ignorance', 'word_no': '803', 'valence_mean': '3.0699999999999998', 'valence_sd': '2.25', 'arousal_mean': '4.3899999999999997', 'arousal_sd': '2.4900000000000002', 'dominance_mean': '4.4100000000000001', 'dominance_sd': '2.3799999999999999', 'word_frequency': '16'}
#
# {'valence': 'neg', 'pres_num': 2, 'cond': 'repeated', 'description': 'ignorance', 'word_no': '803', 'valence_mean': '3.0699999999999998', 'valence_sd': '2.25', 'arousal_mean': '4.3899999999999997', 'arousal_sd': '2.4900000000000002', 'dominance_mean': '4.4100000000000001', 'dominance_sd': '2.3799999999999999', 'word_frequency': '16'}
#
# {'valence': 'neu', 'pres_num': 1, 'cond': 'refreshed', 'description': 'invest', 'word_no': '824', 'valence_mean': '5.9299999999999997', 'valence_sd': '2.1000000000000001', 'arousal_mean': '5.1200000000000001', 'arousal_sd': '2.4199999999999999', 'dominance_mean': '5.8799999999999999', 'dominance_sd': '1.95', 'word_frequency': '3'}
#
# {'valence': 'neu', 'pres_num': 2, 'cond': 'refreshed', 'description': '+', 'word_no': '824', 'valence_mean': '5.9299999999999997', 'valence_sd': '2.1000000000000001', 'arousal_mean': '5.1200000000000001', 'arousal_sd': '2.4199999999999999', 'dominance_mean': '5.8799999999999999', 'dominance_sd': '1.95', 'word_frequency': '3'}
#
# {'valence': 'neg', 'pres_num': 1, 'cond': 'refreshed', 'description': 'selfish', 'word_no': '382', 'valence_mean': '2.4199999999999999', 'valence_sd': '1.6200000000000001', 'arousal_mean': '5.5', 'arousal_sd': '2.6200000000000001', 'dominance_mean': '4.6399999999999997', 'dominance_sd': '2.3100000000000001', 'word_frequency': '8'}
#
# {'valence': 'neg', 'pres_num': 2, 'cond': 'refreshed', 'description': '+', 'word_no': '382', 'valence_mean': '2.4199999999999999', 'valence_sd': '1.6200000000000001', 'arousal_mean': '5.5', 'arousal_sd': '2.6200000000000001', 'dominance_mean': '4.6399999999999997', 'dominance_sd': '2.3100000000000001', 'word_frequency': '8'}
#
# {'valence': 'pos', 'pres_num': 1, 'cond': 'once-presented', 'description': 'social', 'word_no': '985', 'valence_mean': '6.8799999999999999', 'valence_sd': '1.8200000000000001', 'arousal_mean': '4.9800000000000004', 'arousal_sd': '2.5899999999999999', 'dominance_mean': '5.9100000000000001', 'dominance_sd': '2.0699999999999998', 'word_frequency': '380'}
#
# {'valence': 'neg', 'pres_num': 1, 'cond': 'once-presented', 'description': 'hell', 'word_no': '788', 'valence_mean': '2.2400000000000002', 'valence_sd': '1.6200000000000001', 'arousal_mean': '5.3799999999999999', 'arousal_sd': '2.6200000000000001', 'dominance_mean': '3.2400000000000002', 'dominance_sd': '2.3599999999999999', 'word_frequency': '95'}
#
# {'valence': 'pos', 'pres_num': 1, 'cond': 'repeated', 'description': 'mobility', 'word_no': '881', 'valence_mean': '6.8300000000000001', 'valence_sd': '1.79', 'arousal_mean': '5.0', 'arousal_sd': '2.1800000000000002', 'dominance_mean': '6.4299999999999997', 'dominance_sd': '1.48', 'word_frequency': '8'}
#
# {'valence': 'pos', 'pres_num': 2, 'cond': 'repeated', 'description': 'mobility', 'word_no': '881', 'valence_mean': '6.8300000000000001', 'valence_sd': '1.79', 'arousal_mean': '5.0', 'arousal_sd': '2.1800000000000002', 'dominance_mean': '6.4299999999999997', 'dominance_sd': '1.48', 'word_frequency': '8'}
#
# {'valence': 'pos', 'pres_num': 1, 'cond': 'refreshed', 'description': 'honor', 'word_no': '211', 'valence_mean': '7.6600000000000001', 'valence_sd': '1.24', 'arousal_mean': '5.9000000000000004', 'arousal_sd': '1.8300000000000001', 'dominance_mean': '6.7000000000000002', 'dominance_sd': '2.04', 'word_frequency': '66'}
#
# {'valence': 'pos', 'pres_num': 2, 'cond': 'refreshed', 'description': '+', 'word_no': '211', 'valence_mean': '7.6600000000000001', 'valence_sd': '1.24', 'arousal_mean': '5.9000000000000004', 'arousal_sd': '1.8300000000000001', 'dominance_mean': '6.7000000000000002', 'dominance_sd': '2.04', 'word_frequency': '66'}

# %% [markdown]
# Section 4. Create test list, with targets and lures

# %%
test_list = []

for word in temp_study_list:
    new_item = {'type':'target'}
    new_item.update(word)
    test_list.append(new_item)

for i in range(num_words,num_words*2):
    new_item = {'type':'lure'}
    new_item.update(pos_pool[i])
    test_list.append(new_item)
    new_item = {'type':'lure'}
    new_item.update(neg_pool[i])
    test_list.append(new_item)
    new_item = {'type':'lure'}
    new_item.update(neu_pool[i])
    test_list.append(new_item)
    
random.shuffle(test_list)

for word in test_list:
    print(word)
    print()
# Out:
# {'type': 'lure', 'description': 'honest', 'word_no': '210', 'valence_mean': '7.7000000000000002', 'valence_sd': '1.4299999999999999', 'arousal_mean': '5.3200000000000003', 'arousal_sd': '1.9199999999999999', 'dominance_mean': '6.2400000000000002', 'dominance_sd': '2.1299999999999999', 'word_frequency': '47'}
#
# {'type': 'target', 'valence': 'neu', 'pres_num': 1, 'cond': 'repeated', 'description': 'table', 'word_no': '426', 'valence_mean': '5.2199999999999998', 'valence_sd': '0.71999999999999997', 'arousal_mean': '2.9199999999999999', 'arousal_sd': '2.1600000000000001', 'dominance_mean': '4.4699999999999998', 'dominance_sd': '1.6599999999999999', 'word_frequency': '198'}
#
# {'type': 'target', 'valence': 'pos', 'pres_num': 1, 'cond': 'refreshed', 'description': 'honor', 'word_no': '211', 'valence_mean': '7.6600000000000001', 'valence_sd': '1.24', 'arousal_mean': '5.9000000000000004', 'arousal_sd': '1.8300000000000001', 'dominance_mean': '6.7000000000000002', 'dominance_sd': '2.04', 'word_frequency': '66'}
#
# {'type': 'target', 'valence': 'pos', 'pres_num': 1, 'cond': 'once-presented', 'description': 'social', 'word_no': '985', 'valence_mean': '6.8799999999999999', 'valence_sd': '1.8200000000000001', 'arousal_mean': '4.9800000000000004', 'arousal_sd': '2.5899999999999999', 'dominance_mean': '5.9100000000000001', 'dominance_sd': '2.0699999999999998', 'word_frequency': '380'}
#
# {'type': 'lure', 'description': 'quart', 'word_no': '951', 'valence_mean': '5.3899999999999997', 'valence_sd': '2.0099999999999998', 'arousal_mean': '3.5899999999999999', 'arousal_sd': '2.5099999999999998', 'dominance_mean': '5.2000000000000002', 'dominance_sd': '1.8600000000000001', 'word_frequency': '3'}
#
# {'type': 'lure', 'description': 'gripe', 'word_no': '774', 'valence_mean': '3.1400000000000001', 'valence_sd': '1.5600000000000001', 'arousal_mean': '5.0', 'arousal_sd': '2.1899999999999999', 'dominance_mean': '4.6699999999999999', 'dominance_sd': '1.79', 'word_frequency': '.'}
#
# {'type': 'target', 'valence': 'neg', 'pres_num': 1, 'cond': 'repeated', 'description': 'ignorance', 'word_no': '803', 'valence_mean': '3.0699999999999998', 'valence_sd': '2.25', 'arousal_mean': '4.3899999999999997', 'arousal_sd': '2.4900000000000002', 'dominance_mean': '4.4100000000000001', 'dominance_sd': '2.3799999999999999', 'word_frequency': '16'}
#
# {'type': 'target', 'valence': 'neg', 'pres_num': 1, 'cond': 'once-presented', 'description': 'hell', 'word_no': '788', 'valence_mean': '2.2400000000000002', 'valence_sd': '1.6200000000000001', 'arousal_mean': '5.3799999999999999', 'arousal_sd': '2.6200000000000001', 'dominance_mean': '3.2400000000000002', 'dominance_sd': '2.3599999999999999', 'word_frequency': '95'}
#
# {'type': 'target', 'valence': 'pos', 'pres_num': 1, 'cond': 'repeated', 'description': 'mobility', 'word_no': '881', 'valence_mean': '6.8300000000000001', 'valence_sd': '1.79', 'arousal_mean': '5.0', 'arousal_sd': '2.1800000000000002', 'dominance_mean': '6.4299999999999997', 'dominance_sd': '1.48', 'word_frequency': '8'}
#
# {'type': 'lure', 'description': 'hope', 'word_no': '794', 'valence_mean': '7.0499999999999998', 'valence_sd': '1.96', 'arousal_mean': '5.4400000000000004', 'arousal_sd': '2.4700000000000002', 'dominance_mean': '5.5199999999999996', 'dominance_sd': '2.2000000000000002', 'word_frequency': '178'}
#
# {'type': 'lure', 'description': 'coast', 'word_no': '691', 'valence_mean': '5.9800000000000004', 'valence_sd': '1.8600000000000001', 'arousal_mean': '4.5899999999999999', 'arousal_sd': '2.3100000000000001', 'dominance_mean': '5.6699999999999999', 'dominance_sd': '1.71', 'word_frequency': '61'}
#
# {'type': 'lure', 'description': 'pus', 'word_no': '602', 'valence_mean': '2.8599999999999999', 'valence_sd': '1.9099999999999999', 'arousal_mean': '4.8200000000000003', 'arousal_sd': '2.0600000000000001', 'dominance_mean': '4.3499999999999996', 'dominance_sd': '1.8200000000000001', 'word_frequency': '.'}
#
# {'type': 'lure', 'description': 'menace', 'word_no': '275', 'valence_mean': '2.8799999999999999', 'valence_sd': '1.6399999999999999', 'arousal_mean': '5.5199999999999996', 'arousal_sd': '2.4500000000000002', 'dominance_mean': '4.9800000000000004', 'dominance_sd': '2.25', 'word_frequency': '9'}
#
# {'type': 'lure', 'description': 'market', 'word_no': '866', 'valence_mean': '5.6600000000000001', 'valence_sd': '1.02', 'arousal_mean': '4.1200000000000001', 'arousal_sd': '1.8300000000000001', 'dominance_mean': '5.2699999999999996', 'dominance_sd': '1.3999999999999999', 'word_frequency': '155'}
#
# {'type': 'target', 'valence': 'neu', 'pres_num': 1, 'cond': 'refreshed', 'description': 'invest', 'word_no': '824', 'valence_mean': '5.9299999999999997', 'valence_sd': '2.1000000000000001', 'arousal_mean': '5.1200000000000001', 'arousal_sd': '2.4199999999999999', 'dominance_mean': '5.8799999999999999', 'dominance_sd': '1.95', 'word_frequency': '3'}
#
# {'type': 'lure', 'description': 'quick', 'word_no': '953', 'valence_mean': '6.6399999999999997', 'valence_sd': '1.6100000000000001', 'arousal_mean': '6.5700000000000003', 'arousal_sd': '1.78', 'dominance_mean': '6.5700000000000003', 'dominance_sd': '1.9099999999999999', 'word_frequency': '68'}
#
# {'type': 'target', 'valence': 'neu', 'pres_num': 1, 'cond': 'once-presented', 'description': 'concentrate', 'word_no': '78', 'valence_mean': '5.2000000000000002', 'valence_sd': '1.28', 'arousal_mean': '4.6500000000000004', 'arousal_sd': '2.1299999999999999', 'dominance_mean': '4.9699999999999998', 'dominance_sd': '1.75', 'word_frequency': '11'}
#
# {'type': 'target', 'valence': 'neg', 'pres_num': 1, 'cond': 'refreshed', 'description': 'selfish', 'word_no': '382', 'valence_mean': '2.4199999999999999', 'valence_sd': '1.6200000000000001', 'arousal_mean': '5.5', 'arousal_sd': '2.6200000000000001', 'dominance_mean': '4.6399999999999997', 'dominance_sd': '2.3100000000000001', 'word_frequency': '8'}

# %% [markdown]
# Section 5. Combined list

# %%
import pprint

comb_list = [{'study list': fin_study_list}, {'test_list': test_list}]

for l in comb_list:
    pprint.pprint(l)
# Out:
# {'study list': [{'arousal_mean': '2.9199999999999999',
#                  'arousal_sd': '2.1600000000000001',
#                  'cond': 'repeated',
#                  'description': 'table',
#                  'dominance_mean': '4.4699999999999998',
#                  'dominance_sd': '1.6599999999999999',
#                  'pres_num': 1,
#                  'valence': 'neu',
#                  'valence_mean': '5.2199999999999998',
#                  'valence_sd': '0.71999999999999997',
#                  'word_frequency': '198',
#                  'word_no': '426'},
#                 {'arousal_mean': '2.9199999999999999',
#                  'arousal_sd': '2.1600000000000001',
#                  'cond': 'repeated',
#                  'description': 'table',
#                  'dominance_mean': '4.4699999999999998',
#                  'dominance_sd': '1.6599999999999999',
#                  'pres_num': 2,
#                  'valence': 'neu',
#                  'valence_mean': '5.2199999999999998',
#                  'valence_sd': '0.71999999999999997',
#                  'word_frequency': '198',
#                  'word_no': '426'},
#                 {'arousal_mean': '4.6500000000000004',
#                  'arousal_sd': '2.1299999999999999',
#                  'cond': 'once-presented',
#                  'description': 'concentrate',
#                  'dominance_mean': '4.9699999999999998',
#                  'dominance_sd': '1.75',
#                  'pres_num': 1,
#                  'valence': 'neu',
#                  'valence_mean': '5.2000000000000002',
#                  'valence_sd': '1.28',
#                  'word_frequency': '11',
#                  'word_no': '78'},
#                 {'arousal_mean': '4.3899999999999997',
#                  'arousal_sd': '2.4900000000000002',
#                  'cond': 'repeated',
#                  'description': 'ignorance',
#                  'dominance_mean': '4.4100000000000001',
#                  'dominance_sd': '2.3799999999999999',
#                  'pres_num': 1,
#                  'valence': 'neg',
#                  'valence_mean': '3.0699999999999998',
#                  'valence_sd': '2.25',
#                  'word_frequency': '16',
#                  'word_no': '803'},
#                 {'arousal_mean': '4.3899999999999997',
#                  'arousal_sd': '2.4900000000000002',
#                  'cond': 'repeated',
#                  'description': 'ignorance',
#                  'dominance_mean': '4.4100000000000001',
#                  'dominance_sd': '2.3799999999999999',
#                  'pres_num': 2,
#                  'valence': 'neg',
#                  'valence_mean': '3.0699999999999998',
#                  'valence_sd': '2.25',
#                  'word_frequency': '16',
#                  'word_no': '803'},
#                 {'arousal_mean': '5.1200000000000001',
#                  'arousal_sd': '2.4199999999999999',
#                  'cond': 'refreshed',
#                  'description': 'invest',
#                  'dominance_mean': '5.8799999999999999',
#                  'dominance_sd': '1.95',
#                  'pres_num': 1,
#                  'valence': 'neu',
#                  'valence_mean': '5.9299999999999997',
#                  'valence_sd': '2.1000000000000001',
#                  'word_frequency': '3',
#                  'word_no': '824'},
#                 {'arousal_mean': '5.1200000000000001',
#                  'arousal_sd': '2.4199999999999999',
#                  'cond': 'refreshed',
#                  'description': '+',
#                  'dominance_mean': '5.8799999999999999',
#                  'dominance_sd': '1.95',
#                  'pres_num': 2,
#                  'valence': 'neu',
#                  'valence_mean': '5.9299999999999997',
#                  'valence_sd': '2.1000000000000001',
#                  'word_frequency': '3',
#                  'word_no': '824'},
#                 {'arousal_mean': '5.5',
#                  'arousal_sd': '2.6200000000000001',
#                  'cond': 'refreshed',
#                  'description': 'selfish',
#                  'dominance_mean': '4.6399999999999997',
#                  'dominance_sd': '2.3100000000000001',
#                  'pres_num': 1,
#                  'valence': 'neg',
#                  'valence_mean': '2.4199999999999999',
#                  'valence_sd': '1.6200000000000001',
#                  'word_frequency': '8',
#                  'word_no': '382'},
#                 {'arousal_mean': '5.5',
#                  'arousal_sd': '2.6200000000000001',
#                  'cond': 'refreshed',
#                  'description': '+',
#                  'dominance_mean': '4.6399999999999997',
#                  'dominance_sd': '2.3100000000000001',
#                  'pres_num': 2,
#                  'valence': 'neg',
#                  'valence_mean': '2.4199999999999999',
#                  'valence_sd': '1.6200000000000001',
#                  'word_frequency': '8',
#                  'word_no': '382'},
#                 {'arousal_mean': '4.9800000000000004',
#                  'arousal_sd': '2.5899999999999999',
#                  'cond': 'once-presented',
#                  'description': 'social',
#                  'dominance_mean': '5.9100000000000001',
#                  'dominance_sd': '2.0699999999999998',
#                  'pres_num': 1,
#                  'valence': 'pos',
#                  'valence_mean': '6.8799999999999999',
#                  'valence_sd': '1.8200000000000001',
#                  'word_frequency': '380',
#                  'word_no': '985'},
#                 {'arousal_mean': '5.3799999999999999',
#                  'arousal_sd': '2.6200000000000001',
#                  'cond': 'once-presented',
#                  'description': 'hell',
#                  'dominance_mean': '3.2400000000000002',
#                  'dominance_sd': '2.3599999999999999',
#                  'pres_num': 1,
#                  'valence': 'neg',
#                  'valence_mean': '2.2400000000000002',
#                  'valence_sd': '1.6200000000000001',
#                  'word_frequency': '95',
#                  'word_no': '788'},
#                 {'arousal_mean': '5.0',
#                  'arousal_sd': '2.1800000000000002',
#                  'cond': 'repeated',
#                  'description': 'mobility',
#                  'dominance_mean': '6.4299999999999997',
#                  'dominance_sd': '1.48',
#                  'pres_num': 1,
#                  'valence': 'pos',
#                  'valence_mean': '6.8300000000000001',
#                  'valence_sd': '1.79',
#                  'word_frequency': '8',
#                  'word_no': '881'},
#                 {'arousal_mean': '5.0',
#                  'arousal_sd': '2.1800000000000002',
#                  'cond': 'repeated',
#                  'description': 'mobility',
#                  'dominance_mean': '6.4299999999999997',
#                  'dominance_sd': '1.48',
#                  'pres_num': 2,
#                  'valence': 'pos',
#                  'valence_mean': '6.8300000000000001',
#                  'valence_sd': '1.79',
#                  'word_frequency': '8',
#                  'word_no': '881'},
#                 {'arousal_mean': '5.9000000000000004',
#                  'arousal_sd': '1.8300000000000001',
#                  'cond': 'refreshed',
#                  'description': 'honor',
#                  'dominance_mean': '6.7000000000000002',
#                  'dominance_sd': '2.04',
#                  'pres_num': 1,
#                  'valence': 'pos',
#                  'valence_mean': '7.6600000000000001',
#                  'valence_sd': '1.24',
#                  'word_frequency': '66',
#                  'word_no': '211'},
#                 {'arousal_mean': '5.9000000000000004',
#                  'arousal_sd': '1.8300000000000001',
#                  'cond': 'refreshed',
#                  'description': '+',
#                  'dominance_mean': '6.7000000000000002',
#                  'dominance_sd': '2.04',
#                  'pres_num': 2,
#                  'valence': 'pos',
#                  'valence_mean': '7.6600000000000001',
#                  'valence_sd': '1.24',
#                  'word_frequency': '66',
#                  'word_no': '211'}]}
# {'test_list': [{'arousal_mean': '5.3200000000000003',
#                 'arousal_sd': '1.9199999999999999',
#                 'description': 'honest',
#                 'dominance_mean': '6.2400000000000002',
#                 'dominance_sd': '2.1299999999999999',
#                 'type': 'lure',
#                 'valence_mean': '7.7000000000000002',
#                 'valence_sd': '1.4299999999999999',
#                 'word_frequency': '47',
#                 'word_no': '210'},
#                {'arousal_mean': '2.9199999999999999',
#                 'arousal_sd': '2.1600000000000001',
#                 'cond': 'repeated',
#                 'description': 'table',
#                 'dominance_mean': '4.4699999999999998',
#                 'dominance_sd': '1.6599999999999999',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'neu',
#                 'valence_mean': '5.2199999999999998',
#                 'valence_sd': '0.71999999999999997',
#                 'word_frequency': '198',
#                 'word_no': '426'},
#                {'arousal_mean': '5.9000000000000004',
#                 'arousal_sd': '1.8300000000000001',
#                 'cond': 'refreshed',
#                 'description': 'honor',
#                 'dominance_mean': '6.7000000000000002',
#                 'dominance_sd': '2.04',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'pos',
#                 'valence_mean': '7.6600000000000001',
#                 'valence_sd': '1.24',
#                 'word_frequency': '66',
#                 'word_no': '211'},
#                {'arousal_mean': '4.9800000000000004',
#                 'arousal_sd': '2.5899999999999999',
#                 'cond': 'once-presented',
#                 'description': 'social',
#                 'dominance_mean': '5.9100000000000001',
#                 'dominance_sd': '2.0699999999999998',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'pos',
#                 'valence_mean': '6.8799999999999999',
#                 'valence_sd': '1.8200000000000001',
#                 'word_frequency': '380',
#                 'word_no': '985'},
#                {'arousal_mean': '3.5899999999999999',
#                 'arousal_sd': '2.5099999999999998',
#                 'description': 'quart',
#                 'dominance_mean': '5.2000000000000002',
#                 'dominance_sd': '1.8600000000000001',
#                 'type': 'lure',
#                 'valence_mean': '5.3899999999999997',
#                 'valence_sd': '2.0099999999999998',
#                 'word_frequency': '3',
#                 'word_no': '951'},
#                {'arousal_mean': '5.0',
#                 'arousal_sd': '2.1899999999999999',
#                 'description': 'gripe',
#                 'dominance_mean': '4.6699999999999999',
#                 'dominance_sd': '1.79',
#                 'type': 'lure',
#                 'valence_mean': '3.1400000000000001',
#                 'valence_sd': '1.5600000000000001',
#                 'word_frequency': '.',
#                 'word_no': '774'},
#                {'arousal_mean': '4.3899999999999997',
#                 'arousal_sd': '2.4900000000000002',
#                 'cond': 'repeated',
#                 'description': 'ignorance',
#                 'dominance_mean': '4.4100000000000001',
#                 'dominance_sd': '2.3799999999999999',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'neg',
#                 'valence_mean': '3.0699999999999998',
#                 'valence_sd': '2.25',
#                 'word_frequency': '16',
#                 'word_no': '803'},
#                {'arousal_mean': '5.3799999999999999',
#                 'arousal_sd': '2.6200000000000001',
#                 'cond': 'once-presented',
#                 'description': 'hell',
#                 'dominance_mean': '3.2400000000000002',
#                 'dominance_sd': '2.3599999999999999',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'neg',
#                 'valence_mean': '2.2400000000000002',
#                 'valence_sd': '1.6200000000000001',
#                 'word_frequency': '95',
#                 'word_no': '788'},
#                {'arousal_mean': '5.0',
#                 'arousal_sd': '2.1800000000000002',
#                 'cond': 'repeated',
#                 'description': 'mobility',
#                 'dominance_mean': '6.4299999999999997',
#                 'dominance_sd': '1.48',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'pos',
#                 'valence_mean': '6.8300000000000001',
#                 'valence_sd': '1.79',
#                 'word_frequency': '8',
#                 'word_no': '881'},
#                {'arousal_mean': '5.4400000000000004',
#                 'arousal_sd': '2.4700000000000002',
#                 'description': 'hope',
#                 'dominance_mean': '5.5199999999999996',
#                 'dominance_sd': '2.2000000000000002',
#                 'type': 'lure',
#                 'valence_mean': '7.0499999999999998',
#                 'valence_sd': '1.96',
#                 'word_frequency': '178',
#                 'word_no': '794'},
#                {'arousal_mean': '4.5899999999999999',
#                 'arousal_sd': '2.3100000000000001',
#                 'description': 'coast',
#                 'dominance_mean': '5.6699999999999999',
#                 'dominance_sd': '1.71',
#                 'type': 'lure',
#                 'valence_mean': '5.9800000000000004',
#                 'valence_sd': '1.8600000000000001',
#                 'word_frequency': '61',
#                 'word_no': '691'},
#                {'arousal_mean': '4.8200000000000003',
#                 'arousal_sd': '2.0600000000000001',
#                 'description': 'pus',
#                 'dominance_mean': '4.3499999999999996',
#                 'dominance_sd': '1.8200000000000001',
#                 'type': 'lure',
#                 'valence_mean': '2.8599999999999999',
#                 'valence_sd': '1.9099999999999999',
#                 'word_frequency': '.',
#                 'word_no': '602'},
#                {'arousal_mean': '5.5199999999999996',
#                 'arousal_sd': '2.4500000000000002',
#                 'description': 'menace',
#                 'dominance_mean': '4.9800000000000004',
#                 'dominance_sd': '2.25',
#                 'type': 'lure',
#                 'valence_mean': '2.8799999999999999',
#                 'valence_sd': '1.6399999999999999',
#                 'word_frequency': '9',
#                 'word_no': '275'},
#                {'arousal_mean': '4.1200000000000001',
#                 'arousal_sd': '1.8300000000000001',
#                 'description': 'market',
#                 'dominance_mean': '5.2699999999999996',
#                 'dominance_sd': '1.3999999999999999',
#                 'type': 'lure',
#                 'valence_mean': '5.6600000000000001',
#                 'valence_sd': '1.02',
#                 'word_frequency': '155',
#                 'word_no': '866'},
#                {'arousal_mean': '5.1200000000000001',
#                 'arousal_sd': '2.4199999999999999',
#                 'cond': 'refreshed',
#                 'description': 'invest',
#                 'dominance_mean': '5.8799999999999999',
#                 'dominance_sd': '1.95',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'neu',
#                 'valence_mean': '5.9299999999999997',
#                 'valence_sd': '2.1000000000000001',
#                 'word_frequency': '3',
#                 'word_no': '824'},
#                {'arousal_mean': '6.5700000000000003',
#                 'arousal_sd': '1.78',
#                 'description': 'quick',
#                 'dominance_mean': '6.5700000000000003',
#                 'dominance_sd': '1.9099999999999999',
#                 'type': 'lure',
#                 'valence_mean': '6.6399999999999997',
#                 'valence_sd': '1.6100000000000001',
#                 'word_frequency': '68',
#                 'word_no': '953'},
#                {'arousal_mean': '4.6500000000000004',
#                 'arousal_sd': '2.1299999999999999',
#                 'cond': 'once-presented',
#                 'description': 'concentrate',
#                 'dominance_mean': '4.9699999999999998',
#                 'dominance_sd': '1.75',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'neu',
#                 'valence_mean': '5.2000000000000002',
#                 'valence_sd': '1.28',
#                 'word_frequency': '11',
#                 'word_no': '78'},
#                {'arousal_mean': '5.5',
#                 'arousal_sd': '2.6200000000000001',
#                 'cond': 'refreshed',
#                 'description': 'selfish',
#                 'dominance_mean': '4.6399999999999997',
#                 'dominance_sd': '2.3100000000000001',
#                 'pres_num': 1,
#                 'type': 'target',
#                 'valence': 'neg',
#                 'valence_mean': '2.4199999999999999',
#                 'valence_sd': '1.6200000000000001',
#                 'word_frequency': '8',
#                 'word_no': '382'}]}

# %% [markdown]
# Section 6. Randomized Repetition and Trials Blocks as a Function

# %%
def list_gen():
    pos_pool = [] 
    neg_pool = []  
    neu_pool = []
    
    with open('pos_pool.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        pos_pool = [l for l in reader]
    

    with open('neg_pool.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        neg_pool = [l for l in reader]

    with open('neu_pool.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        neu_pool = [l for l in reader]
    
    conditions = ["repeated","refreshed","once-presented"]
    temp_study_list = []
    fin_study_list = []
    num_words = 3

    random.shuffle(pos_pool)
    pos_select = pos_pool[:num_words] #can change number of words here
    for i in range(num_words):
        cond_item = {'valence': 'pos', 'pres_num': 1}
        cond_item.update({'cond': conditions[i%3]})
        cond_item.update(pos_select[i])
        temp_study_list.append(cond_item)
        
    random.shuffle(neg_pool)
    neg_select = neg_pool[:num_words] #can change number of words here
    for i in range(num_words):
        cond_item = {'valence': 'neg', 'pres_num': 1}
        cond_item.update({'cond': conditions[i%3]})
        cond_item.update(neg_select[i])
        temp_study_list.append(cond_item)
        
    random.shuffle(neu_pool)
    neu_select = neu_pool[:num_words] #can change number of words here
    for i in range(num_words):
        cond_item = {'valence': 'neu', 'pres_num': 1}
        cond_item.update({'cond': conditions[i%3]})
        cond_item.update(neu_select[i])
        temp_study_list.append(cond_item)

    random.shuffle(temp_study_list)

    for word in temp_study_list:
        fin_study_list.append(word)
        if word['cond'] == "repeated":
            next_item = deepcopy(word)
            next_item['pres_num'] = 2
            fin_study_list.append(next_item)
        elif word['cond'] == "refreshed":
            next_item = deepcopy(word)
            next_item['description'] = '+'
            next_item['pres_num'] = 2
            fin_study_list.append(next_item)
            
    test_list = []

    for word in temp_study_list:
        new_item = {'type':'target'}
        new_item.update(word)
        test_list.append(new_item)

    for i in range(num_words,num_words*2):
        new_item = {'type':'lure'}
        new_item.update(pos_pool[i])
        test_list.append(new_item)
        new_item = {'type':'lure'}
        new_item.update(neg_pool[i])
        test_list.append(new_item)
        new_item = {'type':'lure'}
        new_item.update(neu_pool[i])
        test_list.append(new_item)
    
    random.shuffle(test_list)
    
    comb_list = [{'study list': fin_study_list}, {'test_list': test_list}]
    
    return comb_list

def gen_trials(num_reps):
    trials = []
    for i in range(num_reps):
        trials.append(list_gen())
        random.shuffle(trials)
    return trials

num_reps = 4
num_blocks = 3

blocks = [gen_trials(num_reps) for block in range(num_blocks)]
#pprint.pprint(blocks)

# %%
print(len(blocks[0][0][0]['study list']))
print(len(blocks[0][1][0]['study list']))
print(len(blocks[0][2][0]['study list']))
print([ i['description'] for i in (blocks[0][2][0]['study list']) ])
print('')
print([ i['description'] for i in (blocks[0][3][0]['study list']) ])
# Out:
# 15
# 15
# 15
# ['cuddle', 'cuddle', 'writer', 'coin', 'coin', 'fraud', '+', 'inhabitant', '+', 'bright', '+', 'melody', 'allergy', 'allergy', 'wounds']
#
# ['radiator', '+', 'taste', 'taste', 'youth', 'poetry', 'rifle', 'circus', '+', 'robber', '+', 'misery', 'misery', 'cabinet', 'cabinet']

# %% [markdown]
# *Sample Output from Prof. Sederberg

# %%
import pickle
blocks = pickle.load(open('refresh_blocks.pickle','rb'))
blocks
# Out:
# [{'study': [{'description': 'infatuation',
#     'word_no': '516',
#     'valence_mean': '6.7300000000000004',
#     'valence_sd': '2.0800000000000001',
#     'arousal_mean': '7.0199999999999996',
#     'arousal_sd': '1.8700000000000001',
#     'dominance_mean': '4.9000000000000004',
#     'dominance_sd': '2.2799999999999998',
#     'word_frequency': '4',
#     'valence': 'pos',
#     'cond': 'once',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'cemetery',
#     'word_no': '65',
#     'valence_mean': '2.6299999999999999',
#     'valence_sd': '1.3999999999999999',
#     'arousal_mean': '4.8200000000000003',
#     'arousal_sd': '2.6600000000000001',
#     'dominance_mean': '4.2699999999999996',
#     'dominance_sd': '2.1400000000000001',
#     'word_frequency': '15',
#     'valence': 'neg',
#     'cond': 'once',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'column',
#     'word_no': '695',
#     'valence_mean': '5.1699999999999999',
#     'valence_sd': '0.84999999999999998',
#     'arousal_mean': '3.6200000000000001',
#     'arousal_sd': '1.9099999999999999',
#     'dominance_mean': '4.8099999999999996',
#     'dominance_sd': '1.5800000000000001',
#     'word_frequency': '71',
#     'valence': 'neu',
#     'cond': 'refresh',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': '+',
#     'word_no': '695',
#     'valence_mean': '5.1699999999999999',
#     'valence_sd': '0.84999999999999998',
#     'arousal_mean': '3.6200000000000001',
#     'arousal_sd': '1.9099999999999999',
#     'dominance_mean': '4.8099999999999996',
#     'dominance_sd': '1.5800000000000001',
#     'word_frequency': '71',
#     'valence': 'neu',
#     'cond': 'refresh',
#     'pres_num': 2,
#     'type': 'target'},
#    {'description': 'health',
#     'word_no': '204',
#     'valence_mean': '6.8099999999999996',
#     'valence_sd': '1.8799999999999999',
#     'arousal_mean': '5.1299999999999999',
#     'arousal_sd': '2.3500000000000001',
#     'dominance_mean': '5.8300000000000001',
#     'dominance_sd': '1.9099999999999999',
#     'word_frequency': '105',
#     'valence': 'pos',
#     'cond': 'repeat',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'health',
#     'word_no': '204',
#     'valence_mean': '6.8099999999999996',
#     'valence_sd': '1.8799999999999999',
#     'arousal_mean': '5.1299999999999999',
#     'arousal_sd': '2.3500000000000001',
#     'dominance_mean': '5.8300000000000001',
#     'dominance_sd': '1.9099999999999999',
#     'word_frequency': '105',
#     'valence': 'pos',
#     'cond': 'repeat',
#     'pres_num': 2,
#     'type': 'target'},
#    {'description': 'fabric',
#     'word_no': '742',
#     'valence_mean': '5.2999999999999998',
#     'valence_sd': '1.2',
#     'arousal_mean': '4.1399999999999997',
#     'arousal_sd': '1.98',
#     'dominance_mean': '5.0300000000000002',
#     'dominance_sd': '1.6100000000000001',
#     'word_frequency': '15',
#     'valence': 'neu',
#     'cond': 'once',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'waterfall',
#     'word_no': '487',
#     'valence_mean': '7.8799999999999999',
#     'valence_sd': '1.03',
#     'arousal_mean': '5.3700000000000001',
#     'arousal_sd': '2.8399999999999999',
#     'dominance_mean': '5.2000000000000002',
#     'dominance_sd': '2.1800000000000002',
#     'word_frequency': '2',
#     'valence': 'pos',
#     'cond': 'refresh',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': '+',
#     'word_no': '487',
#     'valence_mean': '7.8799999999999999',
#     'valence_sd': '1.03',
#     'arousal_mean': '5.3700000000000001',
#     'arousal_sd': '2.8399999999999999',
#     'dominance_mean': '5.2000000000000002',
#     'dominance_sd': '2.1800000000000002',
#     'word_frequency': '2',
#     'valence': 'pos',
#     'cond': 'refresh',
#     'pres_num': 2,
#     'type': 'target'},
#    {'description': 'inferior',
#     'word_no': '812',
#     'valence_mean': '3.0699999999999998',
#     'valence_sd': '1.5700000000000001',
#     'arousal_mean': '3.8300000000000001',
#     'arousal_sd': '2.0499999999999998',
#     'dominance_mean': '2.7799999999999998',
#     'dominance_sd': '2.0800000000000001',
#     'word_frequency': '7',
#     'valence': 'neg',
#     'cond': 'repeat',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'inferior',
#     'word_no': '812',
#     'valence_mean': '3.0699999999999998',
#     'valence_sd': '1.5700000000000001',
#     'arousal_mean': '3.8300000000000001',
#     'arousal_sd': '2.0499999999999998',
#     'dominance_mean': '2.7799999999999998',
#     'dominance_sd': '2.0800000000000001',
#     'word_frequency': '7',
#     'valence': 'neg',
#     'cond': 'repeat',
#     'pres_num': 2,
#     'type': 'target'},
#    {'description': 'maniac',
#     'word_no': '862',
#     'valence_mean': '3.7599999999999998',
#     'valence_sd': '2.0',
#     'arousal_mean': '5.3899999999999997',
#     'arousal_sd': '2.46',
#     'dominance_mean': '4.2199999999999998',
#     'dominance_sd': '2.0699999999999998',
#     'word_frequency': '4',
#     'valence': 'neg',
#     'cond': 'refresh',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': '+',
#     'word_no': '862',
#     'valence_mean': '3.7599999999999998',
#     'valence_sd': '2.0',
#     'arousal_mean': '5.3899999999999997',
#     'arousal_sd': '2.46',
#     'dominance_mean': '4.2199999999999998',
#     'dominance_sd': '2.0699999999999998',
#     'word_frequency': '4',
#     'valence': 'neg',
#     'cond': 'refresh',
#     'pres_num': 2,
#     'type': 'target'},
#    {'description': 'elevator',
#     'word_no': '738',
#     'valence_mean': '5.4400000000000004',
#     'valence_sd': '1.1799999999999999',
#     'arousal_mean': '4.1600000000000001',
#     'arousal_sd': '1.99',
#     'dominance_mean': '4.3200000000000003',
#     'dominance_sd': '1.6899999999999999',
#     'word_frequency': '12',
#     'valence': 'neu',
#     'cond': 'repeat',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'elevator',
#     'word_no': '738',
#     'valence_mean': '5.4400000000000004',
#     'valence_sd': '1.1799999999999999',
#     'arousal_mean': '4.1600000000000001',
#     'arousal_sd': '1.99',
#     'dominance_mean': '4.3200000000000003',
#     'dominance_sd': '1.6899999999999999',
#     'word_frequency': '12',
#     'valence': 'neu',
#     'cond': 'repeat',
#     'pres_num': 2,
#     'type': 'target'}],
#   'test': [{'description': 'fabric',
#     'word_no': '742',
#     'valence_mean': '5.2999999999999998',
#     'valence_sd': '1.2',
#     'arousal_mean': '4.1399999999999997',
#     'arousal_sd': '1.98',
#     'dominance_mean': '5.0300000000000002',
#     'dominance_sd': '1.6100000000000001',
#     'word_frequency': '15',
#     'valence': 'neu',
#     'cond': 'once',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'quarrel',
#     'word_no': '338',
#     'valence_mean': '2.9300000000000002',
#     'valence_sd': '2.0600000000000001',
#     'arousal_mean': '6.29',
#     'arousal_sd': '2.5600000000000001',
#     'dominance_mean': '4.0199999999999996',
#     'dominance_sd': '2.1600000000000001',
#     'word_frequency': '20',
#     'valence': 'neg',
#     'cond': 'repeat',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'infatuation',
#     'word_no': '516',
#     'valence_mean': '6.7300000000000004',
#     'valence_sd': '2.0800000000000001',
#     'arousal_mean': '7.0199999999999996',
#     'arousal_sd': '1.8700000000000001',
#     'dominance_mean': '4.9000000000000004',
#     'dominance_sd': '2.2799999999999998',
#     'word_frequency': '4',
#     'valence': 'pos',
#     'cond': 'once',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'skijump',
#     'word_no': '531',
#     'valence_mean': '7.0599999999999996',
#     'valence_sd': '1.73',
#     'arousal_mean': '7.0599999999999996',
#     'arousal_sd': '2.1000000000000001',
#     'dominance_mean': '4.9000000000000004',
#     'dominance_sd': '2.3199999999999998',
#     'word_frequency': '.',
#     'valence': 'pos',
#     'cond': 'refresh',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'cemetery',
#     'word_no': '65',
#     'valence_mean': '2.6299999999999999',
#     'valence_sd': '1.3999999999999999',
#     'arousal_mean': '4.8200000000000003',
#     'arousal_sd': '2.6600000000000001',
#     'dominance_mean': '4.2699999999999996',
#     'dominance_sd': '2.1400000000000001',
#     'word_frequency': '15',
#     'valence': 'neg',
#     'cond': 'once',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'wagon',
#     'word_no': '1029',
#     'valence_mean': '5.3700000000000001',
#     'valence_sd': '0.96999999999999997',
#     'arousal_mean': '3.98',
#     'arousal_sd': '2.04',
#     'dominance_mean': '5.0499999999999998',
#     'dominance_sd': '1.2',
#     'word_frequency': '55',
#     'valence': 'neu',
#     'cond': 'repeat',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'maniac',
#     'word_no': '862',
#     'valence_mean': '3.7599999999999998',
#     'valence_sd': '2.0',
#     'arousal_mean': '5.3899999999999997',
#     'arousal_sd': '2.46',
#     'dominance_mean': '4.2199999999999998',
#     'dominance_sd': '2.0699999999999998',
#     'word_frequency': '4',
#     'valence': 'neg',
#     'cond': 'refresh',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'scurvy',
#     'word_no': '378',
#     'valence_mean': '3.1899999999999999',
#     'valence_sd': '2.0',
#     'arousal_mean': '4.71',
#     'arousal_sd': '2.7200000000000002',
#     'dominance_mean': '4.4800000000000004',
#     'dominance_sd': '2.48',
#     'word_frequency': '1',
#     'valence': 'neg',
#     'cond': 'once',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'waterfall',
#     'word_no': '487',
#     'valence_mean': '7.8799999999999999',
#     'valence_sd': '1.03',
#     'arousal_mean': '5.3700000000000001',
#     'arousal_sd': '2.8399999999999999',
#     'dominance_mean': '5.2000000000000002',
#     'dominance_sd': '2.1800000000000002',
#     'word_frequency': '2',
#     'valence': 'pos',
#     'cond': 'refresh',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'inferior',
#     'word_no': '812',
#     'valence_mean': '3.0699999999999998',
#     'valence_sd': '1.5700000000000001',
#     'arousal_mean': '3.8300000000000001',
#     'arousal_sd': '2.0499999999999998',
#     'dominance_mean': '2.7799999999999998',
#     'dominance_sd': '2.0800000000000001',
#     'word_frequency': '7',
#     'valence': 'neg',
#     'cond': 'repeat',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'scissors',
#     'word_no': '974',
#     'valence_mean': '5.0499999999999998',
#     'valence_sd': '0.95999999999999996',
#     'arousal_mean': '4.4699999999999998',
#     'arousal_sd': '1.76',
#     'dominance_mean': '5.1600000000000001',
#     'dominance_sd': '1.8400000000000001',
#     'word_frequency': '1',
#     'valence': 'neu',
#     'cond': 'once',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'elevator',
#     'word_no': '738',
#     'valence_mean': '5.4400000000000004',
#     'valence_sd': '1.1799999999999999',
#     'arousal_mean': '4.1600000000000001',
#     'arousal_sd': '1.99',
#     'dominance_mean': '4.3200000000000003',
#     'dominance_sd': '1.6899999999999999',
#     'word_frequency': '12',
#     'valence': 'neu',
#     'cond': 'repeat',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'treasure',
#     'word_no': '449',
#     'valence_mean': '8.2699999999999996',
#     'valence_sd': '0.90000000000000002',
#     'arousal_mean': '6.75',
#     'arousal_sd': '2.2999999999999998',
#     'dominance_mean': '6.3600000000000003',
#     'dominance_sd': '2.4199999999999999',
#     'word_frequency': '4',
#     'valence': 'pos',
#     'cond': 'once',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'chocolate',
#     'word_no': '505',
#     'valence_mean': '6.8799999999999999',
#     'valence_sd': '1.8899999999999999',
#     'arousal_mean': '5.29',
#     'arousal_sd': '2.5499999999999998',
#     'dominance_mean': '5.1799999999999997',
#     'dominance_sd': '1.97',
#     'word_frequency': '9',
#     'valence': 'pos',
#     'cond': 'repeat',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'damage',
#     'word_no': '712',
#     'valence_mean': '3.0499999999999998',
#     'valence_sd': '1.6499999999999999',
#     'arousal_mean': '5.5700000000000003',
#     'arousal_sd': '2.2599999999999998',
#     'dominance_mean': '3.8799999999999999',
#     'dominance_sd': '1.8600000000000001',
#     'word_frequency': '33',
#     'valence': 'neg',
#     'cond': 'refresh',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'column',
#     'word_no': '695',
#     'valence_mean': '5.1699999999999999',
#     'valence_sd': '0.84999999999999998',
#     'arousal_mean': '3.6200000000000001',
#     'arousal_sd': '1.9099999999999999',
#     'dominance_mean': '4.8099999999999996',
#     'dominance_sd': '1.5800000000000001',
#     'word_frequency': '71',
#     'valence': 'neu',
#     'cond': 'refresh',
#     'pres_num': 1,
#     'type': 'target'},
#    {'description': 'hydrant',
#     'word_no': '564',
#     'valence_mean': '5.0199999999999996',
#     'valence_sd': '0.93000000000000005',
#     'arousal_mean': '3.71',
#     'arousal_sd': '1.75',
#     'dominance_mean': '5.5300000000000002',
#     'dominance_sd': '1.3',
#     'word_frequency': '.',
#     'valence': 'neu',
#     'cond': 'refresh',
#     'type': 'lure',
#     'pres_num': 1},
#    {'description': 'health',
#     'word_no': '204',
#     'valence_mean': '6.8099999999999996',
#     'valence_sd': '1.8799999999999999',
#     'arousal_mean': '5.1299999999999999',
#     'arousal_sd': '2.3500000000000001',
#     'dominance_mean': '5.8300000000000001',
#     'dominance_sd': '1.9099999999999999',
#     'word_frequency': '105',
#     'valence': 'pos',
#     'cond': 'repeat',
#     'pres_num': 1,
#     'type': 'target'}]}]
